# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
RANDOM_SEED = 42
# Get the current directory
# current_dir = os.path.dirname(os.path.abspath(__file__))
current_dir = "C:\\Users\Sumukha\PycharmProjects\Engineering_Projects\Software_Metrics\scripts"
# Construct the relative paths to the images
dataset_path = os.path.join(current_dir, "..", "data", "Crop_recommendation.csv")
saved_model_path = os.path.join(current_dir, "..", "models")

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
#load dataset

df = pd.read_csv(dataset_path)

l_enc = LabelEncoder()
df.Yield = l_enc.fit_transform(df.Yield)

# %%
# Data frame infor
df.info()
# Data describe
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   Yield_type   2200 non-null   object
#  8   Yield        2200 non-null   int32
# dtypes: float64(4), int32(1), int64(3), object(1)
# memory usage: 146.2+ KB
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# ...

# %%
# Splitting categorical and numerical features
numerical_cols = df[["N", "P", "K", "temperature", "humidity", "ph", "rainfall"]]
categorical_cols = df[["Yield_type", "Yield"]]

# Histogram plotting
numerical_cols.hist(figsize=(12, 8))
# Out:
# array([[<AxesSubplot:title={'center':'N'}>,
#         <AxesSubplot:title={'center':'P'}>,
#         <AxesSubplot:title={'center':'K'}>],
#        [<AxesSubplot:title={'center':'temperature'}>,
#         <AxesSubplot:title={'center':'humidity'}>,
#         <AxesSubplot:title={'center':'ph'}>],
#        [<AxesSubplot:title={'center':'rainfall'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

scalar = MinMaxScaler()
scaled_df = scalar.fit_transform(X=df.drop('Yield', 'Yield_type'), y=df['Yield'])
# Out:
# C:\Users\Sumukha\AppData\Local\Temp\ipykernel_4528\2065594976.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   scaled_df = scalar.fit_transform(X=df.drop('Yield', 'Yield_type'), y=df['Yield'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\pythonProject1\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     549 try:
# --> 550     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551 except KeyError:
#
# KeyError: 'Yield_type'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 5>()
#       2 import matplotlib.pyplot as plt
#       4 scalar = MinMaxScaler()
# ...

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# #sns plot
# print(numerical_cols.columns)
# for col in numerical_cols.columns:
#     ax = sns.lmplot(data=df,
#                     x="Yield",
#                     y=col)
#     plt.title(f"yield vs {col}")
#     plt.show()
